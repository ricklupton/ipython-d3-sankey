# %% [markdown]
# # Do Package Manager stuff
# > Use the right tool for the job: there are some things that aren't worth re-engineering in Python. Here are some tools in python and javascript that will help your project be more maintainable

# %%
# !cd .. && pip install -r requirements-dev.txt
# !cd .. && npm install
# !cd .. && bower install

# %% [markdown]
# # Check Style

# %%
# !flake8 ../ipythond3sankey/*.py ../*.py
# !cd .. && npm run jshint
# Out:
# > ipythond3sankey@0.1.0 jshint /home/rick/devel/ipython-d3-sankey
# > ./node_modules/jshint/bin/jshint ipythond3sankey/static/ipythond3sankey/js/*.js
#
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 25, 'n' is already defined.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 85, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 186, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 233, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 270, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 300, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 423, Unexpected use of '>>>'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 448, Expected an assignment or function call and instead saw an expression.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 449, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 458, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 562, Unexpected use of '>>>'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 587, Expected an assignment or function call and instead saw an expression.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 588, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 597, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 599, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 629, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 663, Expected '{' and instead saw 't'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 677, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 709, Expected '{' and instead saw 'Object'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 772, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 812, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 863, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 912, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 947, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1003, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1046, Expected '{' and instead saw 'n'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1067, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1109, Expected '{' and instead saw '++'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1121, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1155, Expected '{' and instead saw 'return'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1172, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1212, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1235, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1315, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1316, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1343, Expected '{' and instead saw 'return'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1448, Expected '{' and instead saw 'return'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1456, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1522, 't' is already defined.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1550, Expected '{' and instead saw '('.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1585, Expected an assignment or function call and instead saw an expression.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1595, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1611, A constructor name should start with an uppercase letter.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1611, Missing '()' invoking a constructor.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1796, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1799, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1838, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1888, Expected a conditional expression and instead saw an assignment.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1890, Expected '{' and instead saw 't'.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1902, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/d3.min.js: line 1, col 1902, Too many errors. (20% scanned).
#
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 10, col 28, Expected '{' and instead saw 'return'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 16, col 28, Expected '{' and instead saw 'return'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 22, col 28, Expected '{' and instead saw 'return'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 28, col 28, Expected '{' and instead saw 'return'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 34, col 28, Expected '{' and instead saw 'return'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 54, col 23, A leading decimal point can be confused with a dot: '.5'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 65, col 12, Bad line breaking before '+'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 66, col 12, Bad line breaking before '+'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 67, col 12, Bad line breaking before '+'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 71, col 30, Expected '{' and instead saw 'return'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 89, col 39, Expected '{' and instead saw 'source'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 90, col 39, Expected '{' and instead saw 'target'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 123, col 8, Don't make functions within a loop.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 166, col 36, A leading decimal point can be confused with a dot: '.99'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 172, col 33, 'initializeNodeDepth' was used before it was defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 189, col 30, 'relaxLeftToRight' was used before it was defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 204, col 30, 'relaxRightToLeft' was used before it was defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 219, col 31, 'resolveCollisions' was used before it was defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 232, col 23, Expected '{' and instead saw 'node'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 245, col 25, Expected '{' and instead saw 'node'.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 1, col 1, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 59, col 16, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 100, col 9, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 101, col 9, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 136, col 18, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 156, col 26, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 158, col 19, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 173, col 16, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 174, col 63, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 193, col 21, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 193, col 64, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 208, col 21, 'd3' is not defined.
# ipythond3sankey/static/ipythond3sankey/js/sankey.js: line 208, col 64, 'd3' is not defined.
#
# ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js: line 139, col 27, Did you mean to return a conditional instead of an assignment?
# ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js: line 155, col 27, Missing semicolon.
# ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js: line 157, col 24, 'dragmove' was used before it was defined.
# ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js: line 158, col 19, Possible strict violation.
#
# 88 errors
#
# npm ERR! Linux 4.0.6-300.fc22.x86_64
# npm ERR! argv "node" "/usr/bin/npm" "run" "jshint"
# npm ERR! node v0.10.36
# npm ERR! npm  v2.6.1
# npm ERR! code ELIFECYCLE
# npm ERR! ipythond3sankey@0.1.0 jshint: `./node_modules/jshint/bin/jshint ipythond3sankey/static/ipythond3sankey/js/*.js`
# npm ERR! Exit status 2
# npm ERR!
# npm ERR! Failed at the ipythond3sankey@0.1.0 jshint script './node_modules/jshint/bin/jshint ipythond3sankey/static/ipythond3sankey/js/*.js'.
# npm ERR! This is most likely a problem with the ipythond3sankey package,
# npm ERR! not with npm itself.
# npm ERR! Tell the author that this fails on your system:
# npm ERR!     ./node_modules/jshint/bin/jshint ipythond3sankey/static/ipythond3sankey/js/*.js
# npm ERR! You can get their info via:
# npm ERR!     npm owner ls ipythond3sankey
# npm ERR! There is likely additional logging output above.
#
# npm ERR! Please include the following file with any support request:
# npm ERR!     /home/rick/devel/ipython-d3-sankey/npm-debug.log

# %% [markdown]
# # Transpile JS/CSS

# %%
# !cd .. && npm run less

# %% [markdown]
# ## Run Tests

# %%
# !cd .. && PYTHONWARNINGS=ignore python setup.py test
# Out:
# No local packages or download links found for IPython<5.0.0,>=4.0.0
# Traceback (most recent call last):
#   File "setup.py", line 61, in <module>
#     cmdclass=cmdclass('ipythond3sankey/static/ipythond3sankey')
#   File "/home/rick/anaconda3/lib/python3.4/distutils/core.py", line 108, in setup
#     _setup_distribution = dist = klass(attrs)
#   File "/home/rick/anaconda3/lib/python3.4/site-packages/setuptools-16.0-py3.4.egg/setuptools/dist.py", line 268, in __init__
#   File "/home/rick/anaconda3/lib/python3.4/site-packages/setuptools-16.0-py3.4.egg/setuptools/dist.py", line 313, in fetch_build_eggs
#   File "/home/rick/anaconda3/lib/python3.4/site-packages/setuptools-16.0-py3.4.egg/pkg_resources/__init__.py", line 830, in resolve
#   File "/home/rick/anaconda3/lib/python3.4/site-packages/setuptools-16.0-py3.4.egg/pkg_resources/__init__.py", line 1075, in best_match
#   File "/home/rick/anaconda3/lib/python3.4/site-packages/setuptools-16.0-py3.4.egg/pkg_resources/__init__.py", line 1087, in obtain
#   File "/home/rick/anaconda3/lib/python3.4/site-packages/setuptools-16.0-py3.4.egg/setuptools/dist.py", line 380, in fetch_build_egg
#   File "/home/rick/anaconda3/lib/python3.4/site-packages/setuptools-16.0-py3.4.egg/setuptools/command/easy_install.py", line 623, in easy_install
# distutils.errors.DistutilsError: Could not find suitable distribution for Requirement.parse('IPython<5.0.0,>=4.0.0')

# %% [markdown]
# # Generate READMEs

# %%
# !ipython nbconvert README.ipynb --to=rst --stdout > ../README.rst
# Out:
# [NbConvertApp] Converting notebook README.ipynb to rst

# %% [markdown]
# # PyPi: release dry run

# %%
# !cd .. && python setup.py register -r pypitest
# !cd .. && python setup.py sdist
# !cd .. && python setup.py bdist_wheel
# !cd .. && python setup.py sdist upload -r pypitest
# !cd .. && python setup.py bdist_wheel upload -r pypitest
# Out:
# /home/rick/src/notebook/src/ipython/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# running register
# running egg_info
# writing top-level names to ipython_d3_sankey.egg-info/top_level.txt
# writing requirements to ipython_d3_sankey.egg-info/requires.txt
# writing ipython_d3_sankey.egg-info/PKG-INFO
# writing dependency_links to ipython_d3_sankey.egg-info/dependency_links.txt
# reading manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'AUTHORS.rst'
# warning: no files found matching 'CONTRIBUTING.rst'
# warning: no files found matching 'HISTORY.rst'
# warning: no files found matching '*.rst' under directory 'docs'
# warning: no files found matching 'conf.py' under directory 'docs'
# warning: no files found matching 'Makefile' under directory 'docs'
# warning: no files found matching 'make.bat' under directory 'docs'
# warning: no previously-included files matching '__pycache__' found under directory '*'
# warning: no previously-included files matching '*.py[co]' found under directory '*'
# writing manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# Traceback (most recent call last):
#   File "setup.py", line 61, in <module>
#     cmdclass=cmdclass('ipythond3sankey/static/ipythond3sankey')
#   File "/home/rick/anaconda3/lib/python3.4/distutils/core.py", line 148, in setup
#     dist.run_commands()
#   File "/home/rick/anaconda3/lib/python3.4/distutils/dist.py", line 955, in run_commands
#     self.run_command(cmd)
#   File "/home/rick/anaconda3/lib/python3.4/distutils/dist.py", line 974, in run_command
#     cmd_obj.run()
#   File "/home/rick/anaconda3/lib/python3.4/site-packages/setuptools-16.0-py3.4.egg/setuptools/command/register.py", line 10, in run
#   File "/home/rick/anaconda3/lib/python3.4/distutils/command/register.py", line 45, in run
#     self._set_config()
#   File "/home/rick/anaconda3/lib/python3.4/distutils/command/register.py", line 80, in _set_config
#     raise ValueError('%s not found in .pypirc' % self.repository)
# ValueError: pypitest not found in .pypirc
# /home/rick/src/notebook/src/ipython/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# running sdist
# running egg_info
# writing dependency_links to ipython_d3_sankey.egg-info/dependency_links.txt
# writing requirements to ipython_d3_sankey.egg-info/requires.txt
# writing ipython_d3_sankey.egg-info/PKG-INFO
# writing top-level names to ipython_d3_sankey.egg-info/top_level.txt
# reading manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'AUTHORS.rst'
# warning: no files found matching 'CONTRIBUTING.rst'
# warning: no files found matching 'HISTORY.rst'
# warning: no files found matching '*.rst' under directory 'docs'
# warning: no files found matching 'conf.py' under directory 'docs'
# warning: no files found matching 'Makefile' under directory 'docs'
# warning: no files found matching 'make.bat' under directory 'docs'
# warning: no previously-included files matching '__pycache__' found under directory '*'
# warning: no previously-included files matching '*.py[co]' found under directory '*'
# writing manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# running check
# creating ipython-d3-sankey-0.1.0
# creating ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# creating ipython-d3-sankey-0.1.0/ipythond3sankey
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/css
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static/less
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/tests
# making hard links in ipython-d3-sankey-0.1.0...
# hard linking LICENSE -> ipython-d3-sankey-0.1.0
# hard linking MANIFEST.in -> ipython-d3-sankey-0.1.0
# hard linking README.rst -> ipython-d3-sankey-0.1.0
# hard linking setup.cfg -> ipython-d3-sankey-0.1.0
# hard linking setup.py -> ipython-d3-sankey-0.1.0
# hard linking ipython_d3_sankey.egg-info/PKG-INFO -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/SOURCES.txt -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/dependency_links.txt -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/not-zip-safe -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/requires.txt -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/top_level.txt -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipythond3sankey/__init__.py -> ipython-d3-sankey-0.1.0/ipythond3sankey
# hard linking ipythond3sankey/version.py -> ipython-d3-sankey-0.1.0/ipythond3sankey
# hard linking ipythond3sankey/static/ipythond3sankey/css/widget_d3sankey.css -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/css
# hard linking ipythond3sankey/static/ipythond3sankey/js/.jshintrc -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/ipythond3sankey/js/d3.min.js -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/ipythond3sankey/js/sankey.js -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/ipythond3sankey/js/utils.js -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/less/widget_d3sankey.less -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/less
# hard linking ipythond3sankey/tests/__init__.py -> ipython-d3-sankey-0.1.0/ipythond3sankey/tests
# hard linking ipythond3sankey/tests/test_d3sankey.coffee -> ipython-d3-sankey-0.1.0/ipythond3sankey/tests
# hard linking ipythond3sankey/tests/test_widgets.py -> ipython-d3-sankey-0.1.0/ipythond3sankey/tests
# copying setup.cfg -> ipython-d3-sankey-0.1.0
# Writing ipython-d3-sankey-0.1.0/setup.cfg
# creating dist
# Creating tar archive
# removing 'ipython-d3-sankey-0.1.0' (and everything under it)
# /home/rick/src/notebook/src/ipython/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/ipythond3sankey
# copying ipythond3sankey/__init__.py -> build/lib/ipythond3sankey
# copying ipythond3sankey/version.py -> build/lib/ipythond3sankey
# running egg_info
# writing ipython_d3_sankey.egg-info/PKG-INFO
# writing requirements to ipython_d3_sankey.egg-info/requires.txt
# writing dependency_links to ipython_d3_sankey.egg-info/dependency_links.txt
# writing top-level names to ipython_d3_sankey.egg-info/top_level.txt
# reading manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'AUTHORS.rst'
# warning: no files found matching 'CONTRIBUTING.rst'
# warning: no files found matching 'HISTORY.rst'
# warning: no files found matching '*.rst' under directory 'docs'
# warning: no files found matching 'conf.py' under directory 'docs'
# warning: no files found matching 'Makefile' under directory 'docs'
# warning: no files found matching 'make.bat' under directory 'docs'
# warning: no previously-included files matching '__pycache__' found under directory '*'
# warning: no previously-included files matching '*.py[co]' found under directory '*'
# writing manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# creating build/lib/ipythond3sankey/static
# creating build/lib/ipythond3sankey/static/ipythond3sankey
# creating build/lib/ipythond3sankey/static/ipythond3sankey/css
# copying ipythond3sankey/static/ipythond3sankey/css/widget_d3sankey.css -> build/lib/ipythond3sankey/static/ipythond3sankey/css
# creating build/lib/ipythond3sankey/static/ipythond3sankey/js
# copying ipythond3sankey/static/ipythond3sankey/js/.jshintrc -> build/lib/ipythond3sankey/static/ipythond3sankey/js
# copying ipythond3sankey/static/ipythond3sankey/js/d3.min.js -> build/lib/ipythond3sankey/static/ipythond3sankey/js
# copying ipythond3sankey/static/ipythond3sankey/js/sankey.js -> build/lib/ipythond3sankey/static/ipythond3sankey/js
# copying ipythond3sankey/static/ipythond3sankey/js/utils.js -> build/lib/ipythond3sankey/static/ipythond3sankey/js
# copying ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js -> build/lib/ipythond3sankey/static/ipythond3sankey/js
# creating build/lib/ipythond3sankey/static/less
# copying ipythond3sankey/static/less/widget_d3sankey.less -> build/lib/ipythond3sankey/static/less
# creating build/lib/ipythond3sankey/tests
# copying ipythond3sankey/tests/__init__.py -> build/lib/ipythond3sankey/tests
# copying ipythond3sankey/tests/test_d3sankey.coffee -> build/lib/ipythond3sankey/tests
# copying ipythond3sankey/tests/test_widgets.py -> build/lib/ipythond3sankey/tests
# installing to build/bdist.linux-x86_64/wheel
# running install
# Installing Python module...
# running install_lib
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey
# copying build/lib/ipythond3sankey/__init__.py -> build/bdist.linux-x86_64/wheel/ipythond3sankey
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/tests
# copying build/lib/ipythond3sankey/tests/__init__.py -> build/bdist.linux-x86_64/wheel/ipythond3sankey/tests
# copying build/lib/ipythond3sankey/tests/test_widgets.py -> build/bdist.linux-x86_64/wheel/ipythond3sankey/tests
# copying build/lib/ipythond3sankey/tests/test_d3sankey.coffee -> build/bdist.linux-x86_64/wheel/ipythond3sankey/tests
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static/less
# copying build/lib/ipythond3sankey/static/less/widget_d3sankey.less -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/less
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/css
# copying build/lib/ipythond3sankey/static/ipythond3sankey/css/widget_d3sankey.css -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/css
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/d3.min.js -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/.jshintrc -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/utils.js -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/sankey.js -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/version.py -> build/bdist.linux-x86_64/wheel/ipythond3sankey
# running install_egg_info
# Copying ipython_d3_sankey.egg-info to build/bdist.linux-x86_64/wheel/ipython_d3_sankey-0.1.0-py3.4.egg-info
# running install_scripts
# Installing nbextension ...
# copying /home/rick/devel/ipython-d3-sankey/ipythond3sankey/static/ipythond3sankey/css/widget_d3sankey.css -> /home/rick/.local/share/jupyter/nbextensions/ipythond3sankey/css/widget_d3sankey.css
# copying /home/rick/devel/ipython-d3-sankey/ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js -> /home/rick/.local/share/jupyter/nbextensions/ipythond3sankey/js/widget_d3sankey.js
# copying /home/rick/devel/ipython-d3-sankey/ipythond3sankey/static/ipythond3sankey/js/d3.min.js -> /home/rick/.local/share/jupyter/nbextensions/ipythond3sankey/js/d3.min.js
# copying /home/rick/devel/ipython-d3-sankey/ipythond3sankey/static/ipythond3sankey/js/.jshintrc -> /home/rick/.local/share/jupyter/nbextensions/ipythond3sankey/js/.jshintrc
# copying /home/rick/devel/ipython-d3-sankey/ipythond3sankey/static/ipythond3sankey/js/utils.js -> /home/rick/.local/share/jupyter/nbextensions/ipythond3sankey/js/utils.js
# copying /home/rick/devel/ipython-d3-sankey/ipythond3sankey/static/ipythond3sankey/js/sankey.js -> /home/rick/.local/share/jupyter/nbextensions/ipythond3sankey/js/sankey.js
# creating build/bdist.linux-x86_64/wheel/ipython_d3_sankey-0.1.0.dist-info/WHEEL
# /home/rick/src/notebook/src/ipython/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# running sdist
# running egg_info
# writing dependency_links to ipython_d3_sankey.egg-info/dependency_links.txt
# writing requirements to ipython_d3_sankey.egg-info/requires.txt
# writing ipython_d3_sankey.egg-info/PKG-INFO
# writing top-level names to ipython_d3_sankey.egg-info/top_level.txt
# reading manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'AUTHORS.rst'
# warning: no files found matching 'CONTRIBUTING.rst'
# warning: no files found matching 'HISTORY.rst'
# warning: no files found matching '*.rst' under directory 'docs'
# warning: no files found matching 'conf.py' under directory 'docs'
# warning: no files found matching 'Makefile' under directory 'docs'
# warning: no files found matching 'make.bat' under directory 'docs'
# warning: no previously-included files matching '__pycache__' found under directory '*'
# warning: no previously-included files matching '*.py[co]' found under directory '*'
# writing manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# running check
# creating ipython-d3-sankey-0.1.0
# creating ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# creating ipython-d3-sankey-0.1.0/ipythond3sankey
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/css
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/static/less
# creating ipython-d3-sankey-0.1.0/ipythond3sankey/tests
# making hard links in ipython-d3-sankey-0.1.0...
# hard linking LICENSE -> ipython-d3-sankey-0.1.0
# hard linking MANIFEST.in -> ipython-d3-sankey-0.1.0
# hard linking README.rst -> ipython-d3-sankey-0.1.0
# hard linking setup.cfg -> ipython-d3-sankey-0.1.0
# hard linking setup.py -> ipython-d3-sankey-0.1.0
# hard linking ipython_d3_sankey.egg-info/PKG-INFO -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/SOURCES.txt -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/dependency_links.txt -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/not-zip-safe -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/requires.txt -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipython_d3_sankey.egg-info/top_level.txt -> ipython-d3-sankey-0.1.0/ipython_d3_sankey.egg-info
# hard linking ipythond3sankey/__init__.py -> ipython-d3-sankey-0.1.0/ipythond3sankey
# hard linking ipythond3sankey/version.py -> ipython-d3-sankey-0.1.0/ipythond3sankey
# hard linking ipythond3sankey/static/ipythond3sankey/css/widget_d3sankey.css -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/css
# hard linking ipythond3sankey/static/ipythond3sankey/js/.jshintrc -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/ipythond3sankey/js/d3.min.js -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/ipythond3sankey/js/sankey.js -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/ipythond3sankey/js/utils.js -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/ipythond3sankey/js
# hard linking ipythond3sankey/static/less/widget_d3sankey.less -> ipython-d3-sankey-0.1.0/ipythond3sankey/static/less
# hard linking ipythond3sankey/tests/__init__.py -> ipython-d3-sankey-0.1.0/ipythond3sankey/tests
# hard linking ipythond3sankey/tests/test_d3sankey.coffee -> ipython-d3-sankey-0.1.0/ipythond3sankey/tests
# hard linking ipythond3sankey/tests/test_widgets.py -> ipython-d3-sankey-0.1.0/ipythond3sankey/tests
# copying setup.cfg -> ipython-d3-sankey-0.1.0
# Writing ipython-d3-sankey-0.1.0/setup.cfg
# Creating tar archive
# removing 'ipython-d3-sankey-0.1.0' (and everything under it)
# running upload
# Traceback (most recent call last):
#   File "setup.py", line 61, in <module>
#     cmdclass=cmdclass('ipythond3sankey/static/ipythond3sankey')
#   File "/home/rick/anaconda3/lib/python3.4/distutils/core.py", line 148, in setup
#     dist.run_commands()
#   File "/home/rick/anaconda3/lib/python3.4/distutils/dist.py", line 955, in run_commands
#     self.run_command(cmd)
#   File "/home/rick/anaconda3/lib/python3.4/distutils/dist.py", line 974, in run_command
#     cmd_obj.run()
#   File "/home/rick/anaconda3/lib/python3.4/distutils/command/upload.py", line 65, in run
#     self.upload_file(command, pyversion, filename)
#   File "/home/rick/anaconda3/lib/python3.4/distutils/command/upload.py", line 75, in upload_file
#     raise AssertionError("unsupported schema " + schema)
# AssertionError: unsupported schema
# /home/rick/src/notebook/src/ipython/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# running bdist_wheel
# running build
# running build_py
# running egg_info
# writing requirements to ipython_d3_sankey.egg-info/requires.txt
# writing ipython_d3_sankey.egg-info/PKG-INFO
# writing top-level names to ipython_d3_sankey.egg-info/top_level.txt
# writing dependency_links to ipython_d3_sankey.egg-info/dependency_links.txt
# reading manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'AUTHORS.rst'
# warning: no files found matching 'CONTRIBUTING.rst'
# warning: no files found matching 'HISTORY.rst'
# warning: no files found matching '*.rst' under directory 'docs'
# warning: no files found matching 'conf.py' under directory 'docs'
# warning: no files found matching 'Makefile' under directory 'docs'
# warning: no files found matching 'make.bat' under directory 'docs'
# warning: no previously-included files matching '__pycache__' found under directory '*'
# warning: no previously-included files matching '*.py[co]' found under directory '*'
# writing manifest file 'ipython_d3_sankey.egg-info/SOURCES.txt'
# installing to build/bdist.linux-x86_64/wheel
# running install
# Installing Python module...
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey
# copying build/lib/ipythond3sankey/__init__.py -> build/bdist.linux-x86_64/wheel/ipythond3sankey
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/tests
# copying build/lib/ipythond3sankey/tests/__init__.py -> build/bdist.linux-x86_64/wheel/ipythond3sankey/tests
# copying build/lib/ipythond3sankey/tests/test_widgets.py -> build/bdist.linux-x86_64/wheel/ipythond3sankey/tests
# copying build/lib/ipythond3sankey/tests/test_d3sankey.coffee -> build/bdist.linux-x86_64/wheel/ipythond3sankey/tests
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static/less
# copying build/lib/ipythond3sankey/static/less/widget_d3sankey.less -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/less
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/css
# copying build/lib/ipythond3sankey/static/ipythond3sankey/css/widget_d3sankey.css -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/css
# creating build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/widget_d3sankey.js -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/d3.min.js -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/.jshintrc -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/utils.js -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/static/ipythond3sankey/js/sankey.js -> build/bdist.linux-x86_64/wheel/ipythond3sankey/static/ipythond3sankey/js
# copying build/lib/ipythond3sankey/version.py -> build/bdist.linux-x86_64/wheel/ipythond3sankey
# running install_egg_info
# Copying ipython_d3_sankey.egg-info to build/bdist.linux-x86_64/wheel/ipython_d3_sankey-0.1.0-py3.4.egg-info
# running install_scripts
# Installing nbextension ...
# creating build/bdist.linux-x86_64/wheel/ipython_d3_sankey-0.1.0.dist-info/WHEEL
# running upload
# Traceback (most recent call last):
#   File "setup.py", line 61, in <module>
#     cmdclass=cmdclass('ipythond3sankey/static/ipythond3sankey')
#   File "/home/rick/anaconda3/lib/python3.4/distutils/core.py", line 148, in setup
#     dist.run_commands()
#   File "/home/rick/anaconda3/lib/python3.4/distutils/dist.py", line 955, in run_commands
#     self.run_command(cmd)
#   File "/home/rick/anaconda3/lib/python3.4/distutils/dist.py", line 974, in run_command
#     cmd_obj.run()
#   File "/home/rick/anaconda3/lib/python3.4/distutils/command/upload.py", line 65, in run
#     self.upload_file(command, pyversion, filename)
#   File "/home/rick/anaconda3/lib/python3.4/distutils/command/upload.py", line 75, in upload_file
#     raise AssertionError("unsupported schema " + schema)
# AssertionError: unsupported schema

# %% [markdown]
# # PyPi: release

# %%
# !cd .. && python setup.py register -r pypi
# !cd .. && python setup.py sdist
# !cd .. && python setup.py bdist_wheel
# !cd .. && python setup.py sdist upload -r pypi
# !cd .. && python setup.py bdist_wheel upload -r pypi
